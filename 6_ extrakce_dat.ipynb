# %%
from bs4 import BeautifulSoup
import pandas as pd
import re
import requests

# %% [markdown]
# # Extrakce dat z webové stránky do tabulky
#
# ## Příklad
#
# Extrakce dat o 50 nejpopulárnějších knihách ze žánru beletrie.
#
# ### Cíl
#
# Vytvořit tabulku s následujícími sloupci:
#
# - Název knihy
# - Průměrné hodnocení
# - Celkový počet hodnocení
# - Datum vydání

# %%
url = 'https://www.goodreads.com/shelf/show/fiction'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')

# %%
book_title = [
    item.text for item in soup.find_all(attrs={'class':'bookTitle'})
]
book_title
# Out:
# ['To Kill a Mockingbird (To Kill a Mockingbird, #1)',
#  '1984 (Kindle Edition)',
#  'The Great Gatsby (Paperback)',
#  "Harry Potter and the Sorcerer's Stone (Harry Potter, #1)",
#  'Animal Farm (Mass Market Paperback)',
#  'The Catcher in the Rye (Paperback)',
#  'The Hunger Games (The Hunger Games, #1)',
#  'The Da Vinci Code (Robert Langdon, #2)',
#  'The Kite Runner (Paperback)',
#  "The Handmaid's Tale (Paperback)",
#  'Lord of the Flies (Paperback)',
#  'Harry Potter and the Chamber of Secrets (Harry Potter, #2)',
#  'Pride and Prejudice (Paperback)',
#  'The Hobbit or There and Back Again (Paperback)',
#  'Harry Potter and the Prisoner of Azkaban (Harry Potter, #3)',
#  'The Alchemist (Paperback)',
#  'Harry Potter and the Goblet of Fire (Harry Potter, #4)',
#  'Life of Pi (Paperback)',
#  'Catching Fire (The Hunger Games, #2)',
#  'Fahrenheit 451 (Kindle Edition)',
#  'Harry Potter and the Deathly Hallows (Harry Potter, #7)',
#  'The Girl with the Dragon Tattoo (Millennium, #1)',
#  'Harry Potter and the Half-Blood Prince (Harry Potter, #6)',
#  'Harry Potter and the Order of the Phoenix (Harry Potter, #5)',
#  'Brave New World (Paperback)',
#  'Mockingjay (The Hunger Games, #3)',
#  'The Book Thief (Hardcover)',
#  'The Curious Incident of the Dog in the Night-Time (Paperback)',
#  'The Help (Hardcover)',
#  'Of Mice and Men (Paperback)',
#  'Gone Girl (Paperback)',
#  'Angels & Demons (Robert Langdon, #1)',
#  'Slaughterhouse-Five (Paperback)',
#  'Jane Eyre (Paperback)',
#  'The Fault in Our Stars (Hardcover)',
#  "The Time Traveler's Wife (ebook)",
#  'The Lovely Bones (Mass Market Paperback)',
#  'A Game of Thrones (A Song of Ice and Fire, #1)',
#  'Memoirs of a Geisha (Mass Market Paperback)',
#  'Water for Elephants (Paperback)',
#  'The Road (Hardcover)',
#  'The Girl on the Train (Hardcover)',
#  "The Hitchhiker's Guide to the Galaxy (Hitchhiker's Guide to the Galaxy, #1)",
#  'Catch-22 (Catch-22, #1)',
#  'The Adventures of Huckleberry Finn (Paperback)',
#  'One Hundred Years of Solitude (Hardcover)',
#  'The Fellowship of the Ring (The Lord of the Rings, #1)',
#  'Frankenstein (Paperback)',
#  'The Picture of Dorian Gray (Paperback)',
#  'All the Light We Cannot See (Hardcover)']

# %%
year = [
    int(
        re.search(
            "published (\d{4})", 
            item.text.split('—\n')[2]
        ).group(1)
    ) for item in soup.find_all(attrs={'class':'greyText smallText'})]
year
# Out:
# [1960,
#  1949,
#  1926,
#  1997,
#  1945,
#  1951,
#  2008,
#  2003,
#  2003,
#  1985,
#  1954,
#  1998,
#  1813,
#  1937,
#  1999,
#  1988,
#  2000,
#  2001,
#  2009,
#  1953,
#  2007,
#  2005,
#  2005,
#  2003,
#  1932,
#  2010,
#  2005,
#  2003,
#  2009,
#  1937,
#  2012,
#  2000,
#  1969,
#  1847,
#  2012,
#  2003,
#  2002,
#  1996,
#  1997,
#  2006,
#  2006,
#  2015,
#  1979,
#  1961,
#  1884,
#  1967,
#  1954,
#  1818,
#  1890,
#  2014]

# %% [markdown]
# ## Odbočka: Regulární výrazy
#
# Co znamená `re.findall("published (\d{4})", nejaky_text)` se dozvíte v extra [prezentaci](https://sedlakovi.github.io/webscraping/6a_regex.slides.html).

# %%
one_book = soup.find(attrs={'class':'greyText smallText'}).text
one_book
# Out:
# '\n                avg rating 4.27 —\n                4,005,466 ratings  —\n                published 1960\n              '

# %%
# Jde to i jen regexem ;)
match = re.search ('avg rating (\d+\.\d+).+ (\d{1,3}(,\d{3})*).+ published (\d{4})', one_book, re.DOTALL)
print('average rating', match.group(1))
print('total number of ratings', match.group(2).replace(',', ''))
print('year published', match.group(4))
# Out:
# average rating 4.27
# total number of ratings 4005466
# year published 1960

# %%
avg_rating = [
    float(
        re.search("\d+(\.\d+)?", item.text.split('—\n')[0]).group(0)
    ) for item in soup.find_all(attrs={'class':'greyText smallText'})
]
avg_rating
# Out:
# [4.27,
#  4.17,
#  3.91,
#  4.47,
#  3.92,
#  3.8,
#  4.33,
#  3.83,
#  4.29,
#  4.1,
#  3.67,
#  4.41,
#  4.25,
#  4.27,
#  4.56,
#  3.85,
#  4.55,
#  3.9,
#  4.29,
#  3.98,
#  4.62,
#  4.13,
#  4.56,
#  4.49,
#  3.98,
#  4.03,
#  4.37,
#  3.87,
#  4.46,
#  3.86,
#  4.06,
#  3.89,
#  4.07,
#  4.12,
#  4.23,
#  3.96,
#  3.8,
#  4.45,
#  4.1,
#  4.08,
#  3.96,
#  3.91,
#  4.22,
#  3.98,
#  3.81,
#  4.06,
#  4.35,
#  3.78,
#  4.07,
#  4.33]

# %%
total_ratings = [
    int(
        re.search(
            "(\d{1,3}(,\d{3})*)", 
            item.text.split('—\n')[1]
        ).group(1).replace(',', '')) 
    for item in soup.find_all(attrs={'class':'greyText smallText'})]
total_ratings
# Out:
# [4005466,
#  2662838,
#  3342907,
#  6080900,
#  2396393,
#  2464757,
#  5796273,
#  1743300,
#  2195449,
#  1162443,
#  2024675,
#  2350786,
#  2625608,
#  2568490,
#  2395757,
#  1797825,
#  2242177,
#  1211687,
#  2225161,
#  1450591,
#  2414777,
#  2327809,
#  2137088,
#  2190514,
#  1284279,
#  2094209,
#  1608698,
#  1076272,
#  1909231,
#  1752569,
#  2020964,
#  2417176,
#  1031816,
#  1464578,
#  3093784,
#  1459913,
#  1855760,
#  1794998,
#  1587334,
#  1262666,
#  649375,
#  1763902,
#  1255963,
#  670032,
#  1085937,
#  671673,
#  2131165,
#  1038524,
#  835335,
#  833659]

# %%
books = pd.DataFrame(
    zip(book_title, avg_rating, total_ratings, year), 
    columns=['Title', 'Average ratings', 'Total ratings', 'Year published']
)
books
# Out:
#                                                 Title  Average ratings  \
# 0   To Kill a Mockingbird (To Kill a Mockingbird, #1)             4.27
# 1                               1984 (Kindle Edition)             4.17
# 2                        The Great Gatsby (Paperback)             3.91
# 3   Harry Potter and the Sorcerer's Stone (Harry P...             4.47
# 4                 Animal Farm (Mass Market Paperback)             3.92
# 5                  The Catcher in the Rye (Paperback)             3.80
# 6             The Hunger Games (The Hunger Games, #1)             4.33
# 7              The Da Vinci Code (Robert Langdon, #2)             3.83
# 8                         The Kite Runner (Paperback)             4.29
# 9                     The Handmaid's Tale (Paperback)             4.10
# 10                      Lord of the Flies (Paperback)             3.67
# 11  Harry Potter and the Chamber of Secrets (Harry...             4.41
# 12                    Pride and Prejudice (Paperback)             4.25
# 13     The Hobbit or There and Back Again (Paperback)             4.27
# 14  Harry Potter and the Prisoner of Azkaban (Harr...             4.56
# 15                          The Alchemist (Paperback)             3.85
# 16  Harry Potter and the Goblet of Fire (Harry Pot...             4.55
# 17                             Life of Pi (Paperback)             3.90
# 18               Catching Fire (The Hunger Games, #2)             4.29
# 19                    Fahrenheit 451 (Kindle Edition)             3.98
# 20  Harry Potter and the Deathly Hallows (Harry Po...             4.62
# 21   The Girl with the Dragon Tattoo (Millennium, #1)             4.13
# 22  Harry Potter and the Half-Blood Prince (Harry ...             4.56
# 23  Harry Potter and the Order of the Phoenix (Har...             4.49
# 24                        Brave New World (Paperback)             3.98
# 25                  Mockingjay (The Hunger Games, #3)             4.03
# 26                         The Book Thief (Hardcover)             4.37
# 27  The Curious Incident of the Dog in the Night-T...             3.87
# 28                               The Help (Hardcover)             4.46
# 29                        Of Mice and Men (Paperback)             3.86
# 30                              Gone Girl (Paperback)             4.06
# 31               Angels & Demons (Robert Langdon, #1)             3.89
# 32                    Slaughterhouse-Five (Paperback)             4.07
# 33                              Jane Eyre (Paperback)             4.12
# 34                 The Fault in Our Stars (Hardcover)             4.23
# 35                   The Time Traveler's Wife (ebook)             3.96
# 36           The Lovely Bones (Mass Market Paperback)             3.80
# 37     A Game of Thrones (A Song of Ice and Fire, #1)             4.45
# 38        Memoirs of a Geisha (Mass Market Paperback)             4.10
# 39                    Water for Elephants (Paperback)             4.08
# 40                               The Road (Hardcover)             3.96
# 41                  The Girl on the Train (Hardcover)             3.91
# 42  The Hitchhiker's Guide to the Galaxy (Hitchhik...             4.22
# 43                            Catch-22 (Catch-22, #1)             3.98
# 44     The Adventures of Huckleberry Finn (Paperback)             3.81
# 45          One Hundred Years of Solitude (Hardcover)             4.06
# 46  The Fellowship of the Ring (The Lord of the Ri...             4.35
# 47                           Frankenstein (Paperback)             3.78
# 48             The Picture of Dorian Gray (Paperback)             4.07
# 49            All the Light We Cannot See (Hardcover)             4.33
#
#     Total ratings  Year published
# 0         4005466            1960
# 1         2662838            1949
# 2         3342907            1926
# 3         6080900            1997
# 4         2396393            1945
# 5         2464757            1951
# 6         5796273            2008
# 7         1743300            2003
# 8         2195449            2003
# 9         1162443            1985
# 10        2024675            1954
# 11        2350786            1998
# 12        2625608            1813
# 13        2568490            1937
# 14        2395757            1999
# 15        1797825            1988
# 16        2242177            2000
# 17        1211687            2001
# 18        2225161            2009
# 19        1450591            1953
# 20        2414777            2007
# 21        2327809            2005
# 22        2137088            2005
# 23        2190514            2003
# 24        1284279            1932
# 25        2094209            2010
# 26        1608698            2005
# 27        1076272            2003
# 28        1909231            2009
# 29        1752569            1937
# 30        2020964            2012
# 31        2417176            2000
# 32        1031816            1969
# 33        1464578            1847
# 34        3093784            2012
# 35        1459913            2003
# 36        1855760            2002
# 37        1794998            1996
# 38        1587334            1997
# 39        1262666            2006
# 40         649375            2006
# 41        1763902            2015
# 42        1255963            1979
# 43         670032            1961
# 44        1085937            1884
# 45         671673            1967
# 46        2131165            1954
# 47        1038524            1818
# 48         835335            1890
# 49         833659            2014

# %% [markdown]
# Pomocí metody `round` s parametrem `decimals=-1` můžeme zaokrouhlit rok vydání na dekády.

# %%
books['Year published rounded'] = books['Year published'].round(
    decimals=-1
)
books
# Out:
#                                                 Title  Average ratings  \
# 0   To Kill a Mockingbird (To Kill a Mockingbird, #1)             4.27
# 1                               1984 (Kindle Edition)             4.17
# 2                        The Great Gatsby (Paperback)             3.91
# 3   Harry Potter and the Sorcerer's Stone (Harry P...             4.47
# 4                 Animal Farm (Mass Market Paperback)             3.92
# 5                  The Catcher in the Rye (Paperback)             3.80
# 6             The Hunger Games (The Hunger Games, #1)             4.33
# 7              The Da Vinci Code (Robert Langdon, #2)             3.83
# 8                         The Kite Runner (Paperback)             4.29
# 9                     The Handmaid's Tale (Paperback)             4.10
# 10                      Lord of the Flies (Paperback)             3.67
# 11  Harry Potter and the Chamber of Secrets (Harry...             4.41
# 12                    Pride and Prejudice (Paperback)             4.25
# 13     The Hobbit or There and Back Again (Paperback)             4.27
# 14  Harry Potter and the Prisoner of Azkaban (Harr...             4.56
# 15                          The Alchemist (Paperback)             3.85
# 16  Harry Potter and the Goblet of Fire (Harry Pot...             4.55
# 17                             Life of Pi (Paperback)             3.90
# 18               Catching Fire (The Hunger Games, #2)             4.29
# 19                    Fahrenheit 451 (Kindle Edition)             3.98
# 20  Harry Potter and the Deathly Hallows (Harry Po...             4.62
# 21   The Girl with the Dragon Tattoo (Millennium, #1)             4.13
# 22  Harry Potter and the Half-Blood Prince (Harry ...             4.56
# 23  Harry Potter and the Order of the Phoenix (Har...             4.49
# 24                        Brave New World (Paperback)             3.98
# 25                  Mockingjay (The Hunger Games, #3)             4.03
# 26                         The Book Thief (Hardcover)             4.37
# 27  The Curious Incident of the Dog in the Night-T...             3.87
# 28                               The Help (Hardcover)             4.46
# 29                        Of Mice and Men (Paperback)             3.86
# 30                              Gone Girl (Paperback)             4.06
# 31               Angels & Demons (Robert Langdon, #1)             3.89
# 32                    Slaughterhouse-Five (Paperback)             4.07
# 33                              Jane Eyre (Paperback)             4.12
# 34                 The Fault in Our Stars (Hardcover)             4.23
# 35                   The Time Traveler's Wife (ebook)             3.96
# 36           The Lovely Bones (Mass Market Paperback)             3.80
# 37     A Game of Thrones (A Song of Ice and Fire, #1)             4.45
# 38        Memoirs of a Geisha (Mass Market Paperback)             4.10
# 39                    Water for Elephants (Paperback)             4.08
# 40                               The Road (Hardcover)             3.96
# 41                  The Girl on the Train (Hardcover)             3.91
# 42  The Hitchhiker's Guide to the Galaxy (Hitchhik...             4.22
# 43                            Catch-22 (Catch-22, #1)             3.98
# 44     The Adventures of Huckleberry Finn (Paperback)             3.81
# 45          One Hundred Years of Solitude (Hardcover)             4.06
# 46  The Fellowship of the Ring (The Lord of the Ri...             4.35
# 47                           Frankenstein (Paperback)             3.78
# 48             The Picture of Dorian Gray (Paperback)             4.07
# 49            All the Light We Cannot See (Hardcover)             4.33
#
#     Total ratings  Year published  Year published rounded
# 0         4005466            1960                    1960
# 1         2662838            1949                    1950
# 2         3342907            1926                    1930
# 3         6080900            1997                    2000
# 4         2396393            1945                    1940
# 5         2464757            1951                    1950
# 6         5796273            2008                    2010
# 7         1743300            2003                    2000
# 8         2195449            2003                    2000
# 9         1162443            1985                    1980
# 10        2024675            1954                    1950
# 11        2350786            1998                    2000
# 12        2625608            1813                    1810
# 13        2568490            1937                    1940
# 14        2395757            1999                    2000
# 15        1797825            1988                    1990
# 16        2242177            2000                    2000
# 17        1211687            2001                    2000
# 18        2225161            2009                    2010
# 19        1450591            1953                    1950
# 20        2414777            2007                    2010
# 21        2327809            2005                    2000
# 22        2137088            2005                    2000
# 23        2190514            2003                    2000
# 24        1284279            1932                    1930
# 25        2094209            2010                    2010
# 26        1608698            2005                    2000
# 27        1076272            2003                    2000
# 28        1909231            2009                    2010
# 29        1752569            1937                    1940
# 30        2020964            2012                    2010
# 31        2417176            2000                    2000
# 32        1031816            1969                    1970
# 33        1464578            1847                    1850
# 34        3093784            2012                    2010
# 35        1459913            2003                    2000
# 36        1855760            2002                    2000
# 37        1794998            1996                    2000
# 38        1587334            1997                    2000
# 39        1262666            2006                    2010
# 40         649375            2006                    2010
# 41        1763902            2015                    2020
# 42        1255963            1979                    1980
# 43         670032            1961                    1960
# 44        1085937            1884                    1880
# 45         671673            1967                    1970
# 46        2131165            1954                    1950
# 47        1038524            1818                    1820
# 48         835335            1890                    1890
# 49         833659            2014                    2010

# %% [markdown]
# Toto zaokrouhlení se ale nehodí pro dekády. Níže jsou uvedeny 2 způsoby jak se dá vytvořit sloupec s dekádou.

# %%
import numpy as np
(np.floor((books['Year published'] / 10)) *10).astype(int)
# Out:
# 0     1960
# 1     1940
# 2     1920
# 3     1990
# 4     1940
# 5     1950
# 6     2000
# 7     2000
# 8     2000
# 9     1980
# 10    1950
# 11    1990
# 12    1810
# 13    1930
# 14    1990
# 15    1980
# 16    2000
# 17    2000
# 18    2000
# 19    1950
# 20    2000
# 21    2000
# 22    2000
# 23    2000
# 24    1930
# 25    2010
# 26    2000
# 27    2000
# 28    2000
# 29    1930
# 30    2010
# 31    2000
# 32    1960
# 33    1840
# 34    2010
# 35    2000
# 36    2000
# 37    1990
# 38    1990
# 39    2000
# 40    2000
# 41    2010
# 42    1970
# 43    1960
# 44    1880
# 45    1960
# 46    1950
# 47    1810
# 48    1890
# 49    2010
# Name: Year published, dtype: int64

# %%
books['Decade'] = books['Year published'].astype(str).str.replace(
    '(\d{3})\d', '\g<1>0', regex=True
).astype(int)

# %%
books.groupby('Decade').size()
# Out:
# Decade
# 1810     2
# 1840     1
# 1880     1
# 1890     1
# 1920     1
# 1930     3
# 1940     2
# 1950     4
# 1960     4
# 1970     1
# 1980     2
# 1990     5
# 2000    18
# 2010     5
# dtype: int64

# %% [markdown]
# ## Malá odbočka - filtrování tabulky
#
# ```
# data[podmínka]
#
# data[(podmínka1) & (podmínka2)]
# ```
#
# Pro kombinování podmínek lze použit následující operatory:
# - `&` zároveň
# - `|` nebo
# - `~` ne

# %%
# Vybereme knihy, vydané před rokem 2000 s průměrným hodnocením více než 4.0
books[(books['Year published'] < 2000) & (books['Average ratings'] > 4.0)]
# Out:
#                                                 Title  Average ratings  \
# 0   To Kill a Mockingbird (To Kill a Mockingbird, #1)             4.27
# 1                               1984 (Kindle Edition)             4.17
# 3   Harry Potter and the Sorcerer's Stone (Harry P...             4.47
# 9                     The Handmaid's Tale (Paperback)             4.10
# 11  Harry Potter and the Chamber of Secrets (Harry...             4.41
# 12                    Pride and Prejudice (Paperback)             4.25
# 13     The Hobbit or There and Back Again (Paperback)             4.27
# 14  Harry Potter and the Prisoner of Azkaban (Harr...             4.56
# 32                    Slaughterhouse-Five (Paperback)             4.07
# 33                              Jane Eyre (Paperback)             4.12
# 37     A Game of Thrones (A Song of Ice and Fire, #1)             4.45
# 38        Memoirs of a Geisha (Mass Market Paperback)             4.10
# 42  The Hitchhiker's Guide to the Galaxy (Hitchhik...             4.22
# 45          One Hundred Years of Solitude (Hardcover)             4.06
# 46  The Fellowship of the Ring (The Lord of the Ri...             4.35
# 48             The Picture of Dorian Gray (Paperback)             4.07
#
#     Total ratings  Year published  Year published rounded  Decade
# 0         4005466            1960                    1960    1960
# 1         2662838            1949                    1950    1940
# 3         6080900            1997                    2000    1990
# 9         1162443            1985                    1980    1980
# 11        2350786            1998                    2000    1990
# 12        2625608            1813                    1810    1810
# 13        2568490            1937                    1940    1930
# 14        2395757            1999                    2000    1990
# 32        1031816            1969                    1970    1960
# 33        1464578            1847                    1850    1840
# 37        1794998            1996                    2000    1990
# 38        1587334            1997                    2000    1990
# 42        1255963            1979                    1980    1970
# 45         671673            1967                    1970    1960
# 46        2131165            1954                    1950    1950
# 48         835335            1890                    1890    1890

# %% [markdown]
# # Cvičení 6.1
#
# 1. Ze stránek s mobilními telefony na heurece [https://mobilni-telefony.heureka.cz/](https://mobilni-telefony.heureka.cz/) vytvořte tabulku s následujícími sloupci:
#     - Název telefona
#     - Hodnocení
#     - Počet recenzí
#     - Minimální cena
#     - Maximální cena
# 2. Vytvořte sloupec, kde zaokrouhlíte minimální cenu na celé tisíce
# 3. Seskupte telefony dle nově vytvořeného sloupce a zjistěte průměrné hodnocení pro každou skupinu

# %% [markdown]
# # Extrakce HTML kódu do tabulky
#
# Lze použit funkci `read_html`, která vyžaduje HTML řetězec (objekt `BeautifulSoup` musí být převeden na `str`).

# %%
url = 'https://www.czso.cz/csu/czso/aktualniinformace'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')

# %%
soup.find(class_="table nu-table")
# Out:
# <table class="table nu-table" style="padding:0.1em; width: 650px; border:1px solid #184D84; margin-left:0.35em;">
# <!--****HLAVICKA*****-->
# <tbody>
# <tr style="background-color:#0D7ABC">
# <td style="text-align: center; vertical-align: middle; width: 48%;">
# <span style="color: #FFFFFF;"><strong>Ukazatel</strong></span></td>
# <td style="text-align: center; vertical-align: middle; width: 18%;">
# <span style="color: #FFFFFF;"><strong>Období</strong></span></td>
# <td align="center" valign="top" width="18%">
# <span style="color: #FFFFFF;"><strong>Meziroční<br/>
# 					růst/pokles<br/>
# 					(v %)</strong></span></td>
# <td style="text-align: center; vertical-align: middle; width: 18%;">
# <span style="color: #FFFFFF;"><strong>Datum<br/>
# 					zveřejnění</strong></span></td>
# </tr>
# <!--******** HDP ******-->
# <tr style="background-color:#F1F0F0">
# <td valign="bottom">
# <a href="#11">Hrubý domácí produkt</a></td>
# <td align="center" valign="bottom">
# 					2. čtvrtletí 2019</td>
# <td align="center" valign="bottom">
# <span class="vyvoj RUST" title="2. čtvrtletí 2019">2,7<span> </span></span></td>
# <td align="right" valign="bottom">
# 					14.08.2019</td>
# </tr>
# <!--******** ISC ******-->
# <tr style="background-color:#D4D1D1">
# <td valign="bottom">
# <a href="#12">Index spotřebitelských cen</a></td>
# <td align="center" valign="bottom">
# 					červenec 2019</td>
# <td align="center" valign="bottom">
# <span class="vyvoj RUST" title="červenec 2019">2,9<span> </span></span></td>
# <td align="right" valign="bottom">
# 					12.08.2019</td>
# </tr>
# <tr style="background-color:#F1F0F0">
# <td valign="bottom">
# <a href="#12">Míra inflace</a></td>
# <td align="center" valign="bottom">
# 					červenec 2019</td>
# <td align="center" valign="bottom">
# <span class="vyvoj RUST" title="červenec 2019">2,6<span> </span></span></td>
# <td align="right" valign="bottom">
# 					12.08.2019</td>
# </tr>
# <!--******** PRU ******-->
# <tr style="background-color:#D4D1D1">
# <td valign="bottom">
# <a href="#13">Průmyslová produkce</a></td>
# <td align="center" valign="bottom">
# 					červen 2019</td>
# <td align="center" valign="bottom">
# <span class="vyvoj POKLES" title="červen 2019">-3,8<span> </span></span></td>
# <td align="right" valign="bottom">
# 					06.08.2019</td>
# </tr>
# <!--******** STA ******-->
# <tr style="background-color:#F1F0F0">
# <td valign="bottom">
# <a href="#14">Stavební produkce</a></td>
# <td align="center" valign="bottom">
# 					červen 2019</td>
# <td align="center" valign="bottom">
# <span class="vyvoj RUST" title="červen 2019">2,4<span> </span></span></td>
# <td align="right" valign="bottom">
# 					06.08.2019</td>
# </tr>
# <!--******** MAL ******-->
# <tr style="background-color:#D4D1D1">
# <td valign="bottom">
# <a href="#15">Tržby v maloobchodě (CZ-NACE 47)</a></td>
# <td align="center" valign="bottom">
# 					červen 2019</td>
# <td align="center" valign="bottom">
# <span class="vyvoj RUST" title="červen 2019">4,6<span> </span></span></td>
# <td align="right" valign="bottom">
# 					07.08.2019</td>
# </tr>
# <!--******** PMZ ******-->
# <tr style="background-color:#F1F0F0">
# <td valign="bottom">
# <a href="#17">Průměrná mzda - nominální</a></td>
# <td align="center" valign="bottom">
# 					1. čtvrtletí 2019</td>
# <td align="center" valign="bottom">
# <span class="vyvoj RUST" title="1. čtvrtletí 2019">7,4<span> </span></span></td>
# <td align="right" valign="bottom">
# 					04.06.2019</td>
# </tr>
# <tr style="background-color:#D4D1D1">
# <td valign="top">
# <a href="#17">Průměrná mzda - reálná</a></td>
# <td align="center" valign="middle">
# 					1. čtvrtletí 2019</td>
# <td align="center">
# <span class="vyvoj RUST" title="1. čtvrtletí 2019">4,6<span> </span></span></td>
# <td align="right" valign="middle">
# 					04.06.2019</td>
# </tr>
# <!--******** IPC ******-->
# <tr style="background-color:#F1F0F0">
# <td valign="top">
# <a href="#18">Indexy cen výrobců - zemědělských</a></td>
# <td align="center" valign="middle">
# 					červenec 2019</td>
# <td align="center">
# <span class="vyvoj RUST" title="červenec 2019">12,1<span> </span></span></td>
# <td align="right" valign="middle">
# 					16.08.2019</td>
# </tr>
# <tr style="background-color:#D4D1D1">
# <td valign="top">
# <a href="#19">Indexy cen výrobců - průmyslových</a></td>
# <td align="center" valign="middle">
# 					červenec 2019</td>
# <td align="center">
# <span class="vyvoj RUST" title="červenec 2019">2,1<span> </span></span></td>
# <td align="right" valign="middle">
# 					16.08.2019</td>
# </tr>
# <tr style="background-color:#F1F0F0">
# <td valign="top">
# <a href="#120">Indexy cen výrobců - stavebních prací</a></td>
# <td align="center" valign="middle">
# 					červenec 2019</td>
# <td align="center">
# <span class="vyvoj RUST" title="červenec 2019">3,9<span> </span></span></td>
# <td align="right" valign="middle">
# 					16.08.2019</td>
# </tr>
# <tr style="background-color:#D4D1D1">
# <td valign="top">
# <a href="#121">Indexy cen výrobců - tržních služeb</a></td>
# <td align="center" valign="middle">
# 					červenec 2019</td>
# <td align="center" valign="top">
# <span class="vyvoj RUST" title="červenec 2019">2,5<span> </span></span></td>
# <td align="right">
# 					16.08.2019</td>
# </tr>
# <!--******** VZO ******-->
# <tr style="background-color:#F1F0F0">
# <td valign="top">
# <a href="#123">Zahraniční obchod - dovoz</a></td>
# <td align="center" valign="middle">
# 					červen 2019</td>
# <td align="center" valign="top">
# <span class="vyvoj POKLES" title="červen 2019">-7,5<span> </span></span></td>
# <td align="right">
# 					06.08.2019</td>
# </tr>
# <tr style="background-color:#D4D1D1">
# <td valign="top">
# <a href="#122">Zahraniční obchod - vývoz</a></td>
# <td align="center" valign="middle">
# 					červen 2019</td>
# <td align="center" valign="top">
# <span class="vyvoj POKLES" title="červen 2019">-4,0<span> </span></span></td>
# <td align="right">
# 					06.08.2019</td>
# </tr>
# <!--******** IZC ******-->
# <tr style="background-color:#F1F0F0">
# <td valign="top">
# <a href="#izc">Indexy cen vývozu a dovozu - dovoz</a></td>
# <td align="center" valign="middle">
# 					červen 2019</td>
# <td align="center" valign="top">
# <span class="vyvoj POKLES" title="červen 2019">-0,7<span> </span></span></td>
# <td align="right">
# 					12.08.2019</td>
# </tr>
# <tr style="background-color:#D4D1D1">
# <td valign="top">
# <a href="#izc">Indexy cen vývozu a dovozu - vývoz</a></td>
# <td align="center" valign="middle">
# 					červen 2019</td>
# <td align="center" valign="middle">
# <span class="vyvoj RUST" title="červen 2019">0,1<span> </span></span></td>
# <td align="right">
# 					12.08.2019</td>
# </tr>
# <!--******** NEZ ******-->
# <tr style="background-color:#F1F0F0">
# <td>
# <a href="#124">Obecná míra nezaměstnanosti</a><sup>*</sup></td>
# <td align="center">
# 					červenec 2019</td>
# <td align="center">
# 					2,2<sup>*</sup></td>
# <td align="right">
# 					29.08.2019</td>
# </tr>
# </tbody>
# </table>

# %%
pd.read_html(str(soup.find(class_="table nu-table")), header=0)[0]
# Out:
#                                  Ukazatel             Období  \
# 0                    Hrubý domácí produkt  2. čtvrtletí 2019
# 1              Index spotřebitelských cen      červenec 2019
# 2                            Míra inflace      červenec 2019
# 3                     Průmyslová produkce        červen 2019
# 4                       Stavební produkce        červen 2019
# 5        Tržby v maloobchodě (CZ-NACE 47)        červen 2019
# 6               Průměrná mzda - nominální  1. čtvrtletí 2019
# 7                  Průměrná mzda - reálná  1. čtvrtletí 2019
# 8       Indexy cen výrobců - zemědělských      červenec 2019
# 9       Indexy cen výrobců - průmyslových      červenec 2019
# 10  Indexy cen výrobců - stavebních prací      červenec 2019
# 11    Indexy cen výrobců - tržních služeb      červenec 2019
# 12              Zahraniční obchod - dovoz        červen 2019
# 13              Zahraniční obchod - vývoz        červen 2019
# 14     Indexy cen vývozu a dovozu - dovoz        červen 2019
# 15     Indexy cen vývozu a dovozu - vývoz        červen 2019
# 16           Obecná míra nezaměstnanosti*      červenec 2019
#
#    Meziroční  růst/pokles  (v %) Datum  zveřejnění
# 0                             27        14.08.2019
# 1                             29        12.08.2019
# 2                             26        12.08.2019
# 3                            -38        06.08.2019
# 4                             24        06.08.2019
# 5                             46        07.08.2019
# 6                             74        04.06.2019
# 7                             46        04.06.2019
# 8                            121        16.08.2019
# 9                             21        16.08.2019
# 10                            39        16.08.2019
# 11                            25        16.08.2019
# 12                           -75        06.08.2019
# 13                           -40        06.08.2019
# 14                           -07        12.08.2019
# 15                            01        12.08.2019
# 16                          2,2*        29.08.2019

# %%
economic_stat = pd.read_html(str(soup.find(class_="table nu-table")), header=0)[0]
economic_stat
# Out:
#                                  Ukazatel             Období  \
# 0                    Hrubý domácí produkt  2. čtvrtletí 2019
# 1              Index spotřebitelských cen      červenec 2019
# 2                            Míra inflace      červenec 2019
# 3                     Průmyslová produkce        červen 2019
# 4                       Stavební produkce        červen 2019
# 5        Tržby v maloobchodě (CZ-NACE 47)        červen 2019
# 6               Průměrná mzda - nominální  1. čtvrtletí 2019
# 7                  Průměrná mzda - reálná  1. čtvrtletí 2019
# 8       Indexy cen výrobců - zemědělských      červenec 2019
# 9       Indexy cen výrobců - průmyslových      červenec 2019
# 10  Indexy cen výrobců - stavebních prací      červenec 2019
# 11    Indexy cen výrobců - tržních služeb      červenec 2019
# 12              Zahraniční obchod - dovoz        červen 2019
# 13              Zahraniční obchod - vývoz        červen 2019
# 14     Indexy cen vývozu a dovozu - dovoz        červen 2019
# 15     Indexy cen vývozu a dovozu - vývoz        červen 2019
# 16           Obecná míra nezaměstnanosti*      červenec 2019
#
#    Meziroční  růst/pokles  (v %) Datum  zveřejnění
# 0                             27        14.08.2019
# 1                             29        12.08.2019
# 2                             26        12.08.2019
# 3                            -38        06.08.2019
# 4                             24        06.08.2019
# 5                             46        07.08.2019
# 6                             74        04.06.2019
# 7                             46        04.06.2019
# 8                            121        16.08.2019
# 9                             21        16.08.2019
# 10                            39        16.08.2019
# 11                            25        16.08.2019
# 12                           -75        06.08.2019
# 13                           -40        06.08.2019
# 14                           -07        12.08.2019
# 15                            01        12.08.2019
# 16                          2,2*        29.08.2019

# %%
economic_stat.tail(1).index
# Out:
# RangeIndex(start=16, stop=17, step=1)

# %%
economic_stat.drop(economic_stat.tail(1).index, inplace=True)

# %%
economic_stat
# Out:
#                                  Ukazatel             Období  \
# 0                    Hrubý domácí produkt  2. čtvrtletí 2019
# 1              Index spotřebitelských cen      červenec 2019
# 2                            Míra inflace      červenec 2019
# 3                     Průmyslová produkce        červen 2019
# 4                       Stavební produkce        červen 2019
# 5        Tržby v maloobchodě (CZ-NACE 47)        červen 2019
# 6               Průměrná mzda - nominální  1. čtvrtletí 2019
# 7                  Průměrná mzda - reálná  1. čtvrtletí 2019
# 8       Indexy cen výrobců - zemědělských      červenec 2019
# 9       Indexy cen výrobců - průmyslových      červenec 2019
# 10  Indexy cen výrobců - stavebních prací      červenec 2019
# 11    Indexy cen výrobců - tržních služeb      červenec 2019
# 12              Zahraniční obchod - dovoz        červen 2019
# 13              Zahraniční obchod - vývoz        červen 2019
# 14     Indexy cen vývozu a dovozu - dovoz        červen 2019
# 15     Indexy cen vývozu a dovozu - vývoz        červen 2019
#
#    Meziroční  růst/pokles  (v %) Datum  zveřejnění
# 0                             27        14.08.2019
# 1                             29        12.08.2019
# 2                             26        12.08.2019
# 3                            -38        06.08.2019
# 4                             24        06.08.2019
# 5                             46        07.08.2019
# 6                             74        04.06.2019
# 7                             46        04.06.2019
# 8                            121        16.08.2019
# 9                             21        16.08.2019
# 10                            39        16.08.2019
# 11                            25        16.08.2019
# 12                           -75        06.08.2019
# 13                           -40        06.08.2019
# 14                           -07        12.08.2019
# 15                            01        12.08.2019

# %% [markdown]
# # Cvičení 6.2
#
# Ze stránek [ministersva financí](https://www.mfcr.cz/cs/verejny-sektor/statni-rozpocet/legislativa-statniho-rozpoctu/2019/rozpocet-resortu-financi-kapitola-312-20-33908) vyextrahujte tabulku rozpočtu.
