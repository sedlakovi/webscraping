# %% [markdown]
# Knihovna `requests` se používá pro HTTP dotazy. Během tohoto workshopu ji budeme použivat pro ziskání zdrojového kódu webové stránky.

# %%
import time

import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Ziskání zdrojového kódu stránky

# %%
r = requests.get('https://www.seznam.cz/')

# %% [markdown]
# Ukázat [status HTTP požadávku](https://developer.mozilla.org/en-US/docs/Web/HTTP/Status)

# %%
r
# Out:
# <Response [200]>

# %% [markdown]
# Ukázat zdrojový kód stránky.

# %%
r.text
# Out:
# '<!DOCTYPE html><html lang="cs" class="html-no-js html-no-flex html-no-column-count html-no-hover"><head><meta charSet="utf-8"/><title data-react-helmet="true">Seznam – najdu tam, co neznám</title><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta content="width=device-width, initial-scale=1, minimal-ui" name="viewport"/><meta name="application-name" content="Seznam.cz"/><meta name="apple-itunes-app" content="app-id=950278657, app-argument=https://www.seznam.cz"/><meta content="/media/img/logo-share-square_v2.png" property="og:image"/><meta http-equiv="x-dns-prefetch-control" content="on"/><link rel="dns-prefetch" href="https://www.novinky.cz/"/><link rel="dns-prefetch" href="https://www.super.cz/"/><link rel="dns-prefetch" href="https://www.sport.cz/"/><link rel="dns-prefetch" href="https://www.stream.cz/"/><link rel="dns-prefetch" href="https://www.prozeny.cz/"/><link rel="dns-prefetch" href="https://tv.seznam.cz/"/><link rel="dns-prefetch" href="https://www.firmy.cz/"/><link rel="dns-prefetch" href="https://www.horoskopy.cz/"/><link rel="dns-prefetch" href="https://www.hry.cz/"/><link rel="dns-prefetch" href="https://www.mapy.cz/"/><link rel="dns-prefetch" href="https://www.sreality.cz/"/><link rel="dns-prefetch" href="https://www.sauto.cz/"/><link rel="dns-prefetch" href="https://www.sdovolena.cz/"/><link rel="dns-prefetch" href="https://search.seznam.cz/"/><link rel="dns-prefetch" href="https://obrazky.seznam.cz/"/><link rel="dns-prefetch" href="https://slovnik.seznam.cz/"/><link rel="dns-prefetch" href="https://videa.seznam.cz/"/><link rel="apple-touch-icon" sizes="76x76" href="/media/img/seznam-icons/apple-touch-icon-76x76.png"/><link rel="apple-touch-icon" sizes="120x120" href="/media/img/seznam-icons/apple-touch-icon-120x120.png"/><link rel="apple-touch-icon" sizes="152x152" href="/media/img/seznam-icons/apple-touch-icon-152x152.png"/><link rel="apple-touch-icon" sizes="180x180" href="/media/img/seznam-icons/apple-touch-icon-180x180.png"/><link rel="icon" sizes="16x16" href="/media/img/seznam-icons/favicon-16x16.png"/><link rel="icon" sizes="32x32" href="/media/img/seznam-icons/favicon-32x32.png"/><link rel="icon" sizes="96x96" href="/media/img/seznam-icons/favicon-96x96.png"/><link rel="icon" sizes="192x192" href="/media/img/seznam-icons/favicon-192x192.png"/><link rel="shortcut icon" href="/media/img/seznam-icons/favicon.ico"/><meta name="msapplication-TileColor" content="#b91d47"/><meta name="msapplication-TileImage" content="/media/img/seznam-icons/mstile-144x144.png"/><meta name="msapplication-config" content="/media/img/seznam-icons/browserconfig.xml"/><meta name="google-site-verification" content="et9w6P5bnsuJiHvQkgmqPTDzRDU2FjObXvRU_hVhy80"/><meta name="google-site-verification" content="bCAGkVxEo7HG0kbCgMssQHU7TZ_KY5T36WFd5M6RVKs"/><link rel="alternate" type="application/rss+xml" title="Seznam.cz" href="https://blog.seznam.cz/sluzby/feed/"/><link rel="search" type="application/opensearchdescription+xml" title="Seznam.cz" href="https://download.seznam.cz/vyhledavani/opensearch/seznam-cz.xml"/><link rel="search" type="application/opensearchdescription+xml" title="Firmy.cz" href="https://download.seznam.cz/vyhledavani/opensearch/firmy-cz.xml"/><link rel="search" type="application/opensearchdescription+xml" title="Mapy.cz" href="https://download.seznam.cz/vyhledavani/opensearch/mapy-cz.xml"/><link rel="search" type="application/opensearchdescription+xml" title="Zboží.cz" href="https://download.seznam.cz/vyhledavani/opensearch/zbozi-cz.xml"/><meta name="theme-color" content="#de0000"/><meta name="apple-mobile-web-app-status-bar-style" content="#de0000"/><meta data-react-helmet="true" name="description" content="Nejnavštěvovanější český internetový portál nabízející vyhledávač, e-mail, aktuální zprávy, předpověď počasí a odkazy, které se mohou hodit."/><link rel="stylesheet" media="all" href="/2.0.283/css/homepage-skin-default.min.css" data-skin-css="true"/><style data-styled="" data-styled-version="5.0.0- ...

# %% [markdown]
# Použití variabilních parametrů u URL adresy.

# %%
# Vybereme recepty hlavních chodů české kuchyně na Vánoce s bramborami
params = {
    'druh[]': '2', 'kuchyne[]': '5', 
    'prilezitost[]': '8', 'kategorie[]': '6'
}

r = requests.get(
    'https://recepty.vareni.cz/vyhledavani/', params=params
)
print(r.url)
# Out:
# https://recepty.vareni.cz/vyhledavani/?druh%5B%5D=2&kuchyne%5B%5D=5&prilezitost%5B%5D=8&kategorie%5B%5D=6

# %% [markdown]
# Stažení JSONu

# %%
json_url = 'http://www.mapakriminality.cz/?do=findNamesIndexesForIdsRange&zoomLevel=1&versionId=1&timeFrom=197&timeTo=197&language=cz&minTime=&maxTime=&crimeTypes=%27101-106%27%2C%27201%27%2C%27141%2C142%2C143%2C151%2C161%2C171%2C173%2C181%2C611%2C612%2C614%27%2C%27131%2C132%27%2C%27371%2C373%27%2C%27372%27%2C%27431%27%2C%27433%2C434%27%2C%27435%27%2C%27635%2C641%2C642%2C643%27%2C%27771%27%2C%27-999%27&crimeType='
r = requests.get(json_url)
r.json()
# Out:
# [{'Code': '0000',
#   'Name': 'KŘP HL. M. PRAHY',
#   'Population': 1235036,
#   'Message': False,
#   'FK_Area_Lookup': '0000',
#   'FoundSum': 3924,
#   'I': 31.772353194563},
#  {'Code': '0100',
#   'Name': 'KŘP STŘEDOČESKÉHO KRAJE',
#   'Population': 1268916,
#   'Message': False,
#   'FK_Area_Lookup': '0100',
#   'FoundSum': 1578,
#   'I': 12.435811353943},
#  {'Code': '0200',
#   'Name': 'KŘP JIHOČESKÉHO KRAJE',
#   'Population': 634443,
#   'Message': False,
#   'FK_Area_Lookup': '0200',
#   'FoundSum': 796,
#   'I': 12.546438371926},
#  {'Code': '0300',
#   'Name': 'KŘP PLZEŇSKÉHO KRAJE',
#   'Population': 571357,
#   'Message': False,
#   'FK_Area_Lookup': '0300',
#   'FoundSum': 885,
#   'I': 15.489440052367},
#  {'Code': '0400',
#   'Name': 'KŘP ÚSTECKÉHO KRAJE',
#   'Population': 828335,
#   'Message': False,
#   'FK_Area_Lookup': '0400',
#   'FoundSum': 1361,
#   'I': 16.430550441548},
#  {'Code': '0500',
#   'Name': 'KŘP KRÁLOVÉHRADECKÉHO KRAJE',
#   'Population': 554155,
#   'Message': False,
#   'FK_Area_Lookup': '0500',
#   'FoundSum': 616,
#   'I': 11.116023495231},
#  {'Code': '0600',
#   'Name': 'KŘP JIHOMORAVSKÉHO KRAJE',
#   'Population': 1162318,
#   'Message': False,
#   'FK_Area_Lookup': '0600',
#   'FoundSum': 1471,
#   'I': 12.655744813382},
#  {'Code': '0700',
#   'Name': 'KŘP MORAVSKOSLEZSKÉHO KRAJE',
#   'Population': 1233622,
#   'Message': False,
#   'FK_Area_Lookup': '0700',
#   'FoundSum': 1817,
#   'I': 14.728985053768},
#  {'Code': 1400,
#   'Name': 'KŘP OLOMOUCKÉHO KRAJE',
#   'Population': 638461,
#   'Message': False,
#   'FK_Area_Lookup': '1400',
#   'FoundSum': 827,
#   'I': 12.953022972429},
#  {'Code': 1500,
#   'Name': 'KŘP ZLÍNSKÉHO KRAJE',
#   'Population': 589790,
#   'Message': False,
#   'FK_Area_Lookup': '1500',
#   'FoundSum': 367,
#   'I': 6.2225537903322},
#  {'Code': 1600,
#   'Name': 'KŘP KRAJE VYSOČINA',
#   'Population': 511946,
#   'Message': False,
#   'FK_Area_Lookup': '1600',
#   'FoundSum': 514,
#   'I': 10.040121419056},
#  {'Code': 1700,
#   'Name': 'KŘP PARDUBICKÉHO KRAJE',
#   'Population': 516123,
#   'Message': False,
#   'FK_Area_Lookup': '1700',
#   'FoundSum': 456,
#   'I': 8.8351032602694},
#  {'Code': 1800,
#   'Name': 'KŘP LIBERECKÉHO KRAJE',
#   'Population': 437894,
#   'Message': False,
#   'FK_Area_Lookup': '1800',
#   'FoundSum': 666,
#   'I': 15.209160207722},
#  {'Code': 1900,
#   'Name': 'KŘP KARLOVARSKÉHO KRAJE',
#   'Population': 303609,
#   'Message': False,
#   'FK_Area_Lookup': '1900',
#   'FoundSum': 517,
#   'I': 17.028480710387}]

# %% [markdown]
# # Cvičení 5.1
#
# Zjistěte na stránkach `https://www.seznam.cz/`, kdo má dnes svátek.

# %% [markdown]
# ## CSS selektory
#
# Knihovna `BeautifulSoup` umožňuje používat CSS selektory pomocí funkcí `select` (najde všechny prvky) a `select_one` (nade první prvek).

# %%
url = 'http://quotes.toscrape.com/'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')

# %%
soup.select_one('div .tag')
# Out:
# <a class="tag" href="/tag/change/page/1/">change</a>

# %%
soup.select('div .tag')
# Out:
# [<a class="tag" href="/tag/change/page/1/">change</a>,
#  <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>,
#  <a class="tag" href="/tag/thinking/page/1/">thinking</a>,
#  <a class="tag" href="/tag/world/page/1/">world</a>,
#  <a class="tag" href="/tag/abilities/page/1/">abilities</a>,
#  <a class="tag" href="/tag/choices/page/1/">choices</a>,
#  <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>,
#  <a class="tag" href="/tag/life/page/1/">life</a>,
#  <a class="tag" href="/tag/live/page/1/">live</a>,
#  <a class="tag" href="/tag/miracle/page/1/">miracle</a>,
#  <a class="tag" href="/tag/miracles/page/1/">miracles</a>,
#  <a class="tag" href="/tag/aliteracy/page/1/">aliteracy</a>,
#  <a class="tag" href="/tag/books/page/1/">books</a>,
#  <a class="tag" href="/tag/classic/page/1/">classic</a>,
#  <a class="tag" href="/tag/humor/page/1/">humor</a>,
#  <a class="tag" href="/tag/be-yourself/page/1/">be-yourself</a>,
#  <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>,
#  <a class="tag" href="/tag/adulthood/page/1/">adulthood</a>,
#  <a class="tag" href="/tag/success/page/1/">success</a>,
#  <a class="tag" href="/tag/value/page/1/">value</a>,
#  <a class="tag" href="/tag/life/page/1/">life</a>,
#  <a class="tag" href="/tag/love/page/1/">love</a>,
#  <a class="tag" href="/tag/edison/page/1/">edison</a>,
#  <a class="tag" href="/tag/failure/page/1/">failure</a>,
#  <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>,
#  <a class="tag" href="/tag/paraphrased/page/1/">paraphrased</a>,
#  <a class="tag" href="/tag/misattributed-eleanor-roosevelt/page/1/">misattributed-eleanor-roosevelt</a>,
#  <a class="tag" href="/tag/humor/page/1/">humor</a>,
#  <a class="tag" href="/tag/obvious/page/1/">obvious</a>,
#  <a class="tag" href="/tag/simile/page/1/">simile</a>,
#  <a class="tag" href="/tag/love/" style="font-size: 28px">love</a>,
#  <a class="tag" href="/tag/inspirational/" style="font-size: 26px">inspirational</a>,
#  <a class="tag" href="/tag/life/" style="font-size: 26px">life</a>,
#  <a class="tag" href="/tag/humor/" style="font-size: 24px">humor</a>,
#  <a class="tag" href="/tag/books/" style="font-size: 22px">books</a>,
#  <a class="tag" href="/tag/reading/" style="font-size: 14px">reading</a>,
#  <a class="tag" href="/tag/friendship/" style="font-size: 10px">friendship</a>,
#  <a class="tag" href="/tag/friends/" style="font-size: 8px">friends</a>,
#  <a class="tag" href="/tag/truth/" style="font-size: 8px">truth</a>,
#  <a class="tag" href="/tag/simile/" style="font-size: 6px">simile</a>]

# %% [markdown]
# # Cvičení 5.2
#
# Na stránkách [dokina.cz](https://dokina.tiscali.cz/program-kin?tab=cinemas) najděte první film (filmy jsou seřazeny abecedně), který se promítal 8.8.2019 v kině Aero (první v seznamu abecedně seřazených kinech).
#
# `Je mi fajn s.r.o.`

# %% [markdown]
# # Web scraping ve smyčce
#
# ## Příklad: seznam českých měst s počtem obyvatel a počtem částí obcí

# %%
import pandas as pd

# %% [markdown]
# Pandas je knihovna pro čištění dat v Pythonu. Má skvělou [dokumentaci](https://pandas.pydata.org/pandas-docs/stable/) a [10-minutový úvod](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html).

# %%
url = 'https://cs.wikipedia.org/wiki/Seznam_m%C4%9Bst_v_%C4%8Cesku'
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')

# %%
soup.select_one('table table a', href=True)
# Out:
# <a href="/wiki/Praha" title="Praha">Praha</a>

# %%
cities_links = soup.select('table table a:not(a[href*="Soubor"])', href=True)
cities_links
# Out:
# [<a href="/wiki/Praha" title="Praha">Praha</a>,
#  <a href="/wiki/Brno" title="Brno">Brno</a>,
#  <a href="/wiki/Ostrava" title="Ostrava">Ostrava</a>,
#  <a href="/wiki/Plze%C5%88" title="Plzeň">Plzeň</a>,
#  <a href="/wiki/Liberec" title="Liberec">Liberec</a>,
#  <a href="/wiki/Olomouc" title="Olomouc">Olomouc</a>,
#  <a href="/wiki/%C4%8Cesk%C3%A9_Bud%C4%9Bjovice" title="České Budějovice">České Budějovice</a>,
#  <a href="/wiki/%C3%9Ast%C3%AD_nad_Labem" title="Ústí nad Labem">Ústí nad Labem</a>,
#  <a href="/wiki/Hradec_Kr%C3%A1lov%C3%A9" title="Hradec Králové">Hradec Králové</a>,
#  <a href="/wiki/Pardubice" title="Pardubice">Pardubice</a>,
#  <a href="/wiki/Zl%C3%ADn" title="Zlín">Zlín</a>,
#  <a href="/wiki/Hav%C3%AD%C5%99ov" title="Havířov">Havířov</a>,
#  <a href="/wiki/Kladno" title="Kladno">Kladno</a>,
#  <a href="/wiki/Most_(m%C4%9Bsto)" title="Most (město)"><b>Most</b></a>,
#  <a href="/wiki/Opava" title="Opava">Opava</a>,
#  <a href="/wiki/Fr%C3%BDdek-M%C3%ADstek" title="Frýdek-Místek">Frýdek-Místek</a>,
#  <a href="/wiki/Karvin%C3%A1" title="Karviná">Karviná</a>,
#  <a href="/wiki/Jihlava" title="Jihlava">Jihlava</a>,
#  <a href="/wiki/Teplice" title="Teplice">Teplice</a>,
#  <a href="/wiki/D%C4%9B%C4%8D%C3%ADn" title="Děčín">Děčín</a>,
#  <a href="/wiki/Karlovy_Vary" title="Karlovy Vary">Karlovy Vary</a>,
#  <a href="/wiki/Chomutov" title="Chomutov">Chomutov</a>,
#  <a href="/wiki/Jablonec_nad_Nisou" title="Jablonec nad Nisou">Jablonec nad Nisou</a>,
#  <a href="/wiki/Mlad%C3%A1_Boleslav" title="Mladá Boleslav">Mladá Boleslav</a>,
#  <a href="/wiki/Prost%C4%9Bjov" title="Prostějov">Prostějov</a>,
#  <a href="/wiki/P%C5%99erov" title="Přerov">Přerov</a>]

# %%
[city['href'] for city in cities_links]
# Out:
# ['/wiki/Praha',
#  '/wiki/Brno',
#  '/wiki/Ostrava',
#  '/wiki/Plze%C5%88',
#  '/wiki/Liberec',
#  '/wiki/Olomouc',
#  '/wiki/%C4%8Cesk%C3%A9_Bud%C4%9Bjovice',
#  '/wiki/%C3%9Ast%C3%AD_nad_Labem',
#  '/wiki/Hradec_Kr%C3%A1lov%C3%A9',
#  '/wiki/Pardubice',
#  '/wiki/Zl%C3%ADn',
#  '/wiki/Hav%C3%AD%C5%99ov',
#  '/wiki/Kladno',
#  '/wiki/Most_(m%C4%9Bsto)',
#  '/wiki/Opava',
#  '/wiki/Fr%C3%BDdek-M%C3%ADstek',
#  '/wiki/Karvin%C3%A1',
#  '/wiki/Jihlava',
#  '/wiki/Teplice',
#  '/wiki/D%C4%9B%C4%8D%C3%ADn',
#  '/wiki/Karlovy_Vary',
#  '/wiki/Chomutov',
#  '/wiki/Jablonec_nad_Nisou',
#  '/wiki/Mlad%C3%A1_Boleslav',
#  '/wiki/Prost%C4%9Bjov',
#  '/wiki/P%C5%99erov']

# %%
cities = []
for city in cities_links:
    cities.append(city.text.strip())
cities
# Out:
# ['Praha',
#  'Brno',
#  'Ostrava',
#  'Plzeň',
#  'Liberec',
#  'Olomouc',
#  'České Budějovice',
#  'Ústí nad Labem',
#  'Hradec Králové',
#  'Pardubice',
#  'Zlín',
#  'Havířov',
#  'Kladno',
#  'Most',
#  'Opava',
#  'Frýdek-Místek',
#  'Karviná',
#  'Jihlava',
#  'Teplice',
#  'Děčín',
#  'Karlovy Vary',
#  'Chomutov',
#  'Jablonec nad Nisou',
#  'Mladá Boleslav',
#  'Prostějov',
#  'Přerov']

# %%
soup.select('table table td[align="right"]')
# Out:
# [<td align="right">1 308 632 <a class="image" href="/wiki/Soubor:Increase2.svg" title="Increase2"><img alt="Increase2" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/10px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/15px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">380 681 <a class="image" href="/wiki/Soubor:Increase2.svg" title="Increase2"><img alt="Increase2" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/10px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/15px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">289 128 <a class="image" href="/wiki/Soubor:Increase_Negative.svg" title="Increase Negative"><img alt="Increase Negative" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/10px-Increase_Negative.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/15px-Increase_Negative.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/20px-Increase_Negative.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">172 441 <a class="image" href="/wiki/Soubor:Increase2.svg" title="Increase2"><img alt="Increase2" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/10px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/15px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">104 445 <a class="image" href="/wiki/Soubor:Increase2.svg" title="Increase2"><img alt="Increase2" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/10px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/15px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">100 523 <a class="image" href="/wiki/Soubor:Increase2.svg" title="Increase2"><img alt="Increase2" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/10px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/15px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">94 014 <a class="image" href="/wiki/Soubor:Increase2.svg" title="Increase2"><img alt="Increase2" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/10px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/15px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">92 952 <a class="image" href="/wiki/Soubor:Increase_Negative.svg" title="Increase Negative"><img alt="Increase Negative" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/10px-Increase_Negative.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/15px-Increase_Negative.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/20px-Increase_Negative.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">92 742 <a class="image" href="/wiki/Soubor:Increase_Negative.svg" title="Increase Negative"><img alt="Increase Negative" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/10px-Increase_Negative.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/15px-Increase_Negative.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/20px-Increase_Negative.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">90 688 <a class="image" href="/wiki/Soubor:Increase2.svg" title="Increase2"><img alt="Increase2" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/10px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/15px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">74 997 <a class="image" href="/wiki/Soubor:Increase2.svg" title="Increase2"><img alt="Increase2" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/10px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/15px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">71 903 <a class="image" href="/wiki/Soubor:Increase_Negative.svg" title="Increase Negative"><img alt="Increase Negative" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/10px-Increase_Negative.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/15px-Increase_Negative.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/20px-Increase_Negative.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">69 054 <a class="image" href="/wiki/Soubor:Increase2.svg" title="Increase2"><img alt="Increase2" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/10px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/15px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">66 186 <a class="image" href="/wiki/Soubor:Increase_Negative.svg" title="Increase Negative"><img alt="Increase Negative" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/10px-Increase_Negative.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/15px-Increase_Negative.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/20px-Increase_Negative.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">56 638 <a class="image" href="/wiki/Soubor:Increase_Negative.svg" title="Increase Negative"><img alt="Increase Negative" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/10px-Increase_Negative.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/15px-Increase_Negative.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/20px-Increase_Negative.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">55 931 <a class="image" href="/wiki/Soubor:Increase_Negative.svg" title="Increase Negative"><img alt="Increase Negative" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/10px-Increase_Negative.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/15px-Increase_Negative.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/20px-Increase_Negative.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">52 824 <a class="image" href="/wiki/Soubor:Increase_Negative.svg" title="Increase Negative"><img alt="Increase Negative" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/10px-Increase_Negative.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/15px-Increase_Negative.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/20px-Increase_Negative.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">50 845 <a class="image" href="/wiki/Soubor:Increase2.svg" title="Increase2"><img alt="Increase2" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/10px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/15px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">49 575 <a class="image" href="/wiki/Soubor:Increase2.svg" title="Increase2"><img alt="Increase2" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/10px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/15px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">48 809 <a class="image" href="/wiki/Soubor:Increase_Negative.svg" title="Increase Negative"><img alt="Increase Negative" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/10px-Increase_Negative.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/15px-Increase_Negative.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/20px-Increase_Negative.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">48 501 <a class="image" href="/wiki/Soubor:Increase_Negative.svg" title="Increase Negative"><img alt="Increase Negative" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/10px-Increase_Negative.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/15px-Increase_Negative.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/20px-Increase_Negative.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">48 720 <a class="image" href="/wiki/Soubor:Increase2.svg" title="Increase2"><img alt="Increase2" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/10px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/15px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">45 802 <a class="image" href="/wiki/Soubor:Increase2.svg" title="Increase2"><img alt="Increase2" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/10px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/15px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">44 489 <a class="image" href="/wiki/Soubor:Increase2.svg" title="Increase2"><img alt="Increase2" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/10px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/15px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/20px-Increase2.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">43 680 <a class="image" href="/wiki/Soubor:Increase_Negative.svg" title="Increase Negative"><img alt="Increase Negative" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/10px-Increase_Negative.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/15px-Increase_Negative.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/20px-Increase_Negative.svg.png 2x" width="10"/></a>
#  </td>,
#  <td align="right">43 186 <a class="image" href="/wiki/Soubor:Increase_Negative.svg" title="Increase Negative"><img alt="Increase Negative" data-file-height="300" data-file-width="300" decoding="async" height="10" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/10px-Increase_Negative.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/15px-Increase_Negative.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/59/Increase_Negative.svg/20px-Increase_Negative.svg.png 2x" width="10"/></a>
#  </td>]

# %%
soup.select('table table td:nth-child(2)')[0].text.strip()
# Out:
# '1 308 632'

# %%
pop_nums_list = soup.select('table table td[align="right"]', href=True)
pop_nums = []
for pop in pop_nums_list:
    pop_nums.append(pop.text.strip())
pop_nums
# Out:
# ['1 308 632',
#  '380 681',
#  '289 128',
#  '172 441',
#  '104 445',
#  '100 523',
#  '94 014',
#  '92 952',
#  '92 742',
#  '90 688',
#  '74 997',
#  '71 903',
#  '69 054',
#  '66 186',
#  '56 638',
#  '55 931',
#  '52 824',
#  '50 845',
#  '49 575',
#  '48 809',
#  '48 501',
#  '48 720',
#  '45 802',
#  '44 489',
#  '43 680',
#  '43 186']

# %%
cities_df = pd.DataFrame(zip(cities, pop_nums), columns=['City', 'Population'])
cities_df
# Out:
#                   City Population
# 0                Praha  1 308 632
# 1                 Brno    380 681
# 2              Ostrava    289 128
# 3                Plzeň    172 441
# 4              Liberec    104 445
# 5              Olomouc    100 523
# 6     České Budějovice     94 014
# 7       Ústí nad Labem     92 952
# 8       Hradec Králové     92 742
# 9            Pardubice     90 688
# 10                Zlín     74 997
# 11             Havířov     71 903
# 12              Kladno     69 054
# 13                Most     66 186
# 14               Opava     56 638
# 15       Frýdek-Místek     55 931
# 16             Karviná     52 824
# 17             Jihlava     50 845
# 18             Teplice     49 575
# 19               Děčín     48 809
# 20        Karlovy Vary     48 501
# 21            Chomutov     48 720
# 22  Jablonec nad Nisou     45 802
# 23      Mladá Boleslav     44 489
# 24           Prostějov     43 680
# 25              Přerov     43 186

# %% [markdown]
# ## Stahování ve smyčce
#
# Při procházení smyčkou přidáme vždy `time.sleep(1)`, abychom omezili rychlost našich dotazů (slušnost vůči provozovateli stránky).
#
# Abychom viděli, že se něco děje, můžeme si vypisovat jméno města, nebo jen tečky.

# %%
city = cities_links[0]
city['href']
# Out:
# '/wiki/Praha'

# %% [markdown]
# Metoda `format` umožňuje vytvářet řetězce s variabilním obsahem. [Tyto stránky](https://pyformat.info/) obsahují spoustu příkladů.

# %%
'https://cs.wikipedia.org{}'.format(city['href'])
# Out:
# 'https://cs.wikipedia.org/wiki/Praha'

# %%
url = 'https://cs.wikipedia.org{}'.format(city['href'])
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')
soup.select_one('.infobox a[title*="Část obce"]')
# Out:
# <a href="/wiki/%C4%8C%C3%A1st_obce" title="Část obce">místních částí</a>

# %%
url = 'https://cs.wikipedia.org{}'.format(city['href'])
r = requests.get(url)
soup = BeautifulSoup(r.text, 'html.parser')
soup.select_one('.infobox a[title*="Část obce"]').find_next('td').contents[0]
# Out:
# '146\n'

# %%
municipalities = []
for city in cities_links:
    time.sleep(1)
    print('.', end='')
    
    url = 'https://cs.wikipedia.org/{}'.format(city['href'])
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    municipalities.append(soup.select_one('.infobox a[title*="Část obce"]').find_next('td').contents[0].strip())
cities_df['Municipalities number'] = municipalities
cities_df
# Out:
# ..........................
#                   City Population Municipalities number
# 0                Praha  1 308 632                   146
# 1                 Brno    380 681                    48
# 2              Ostrava    289 128                    37
# 3                Plzeň    172 441                    31
# 4              Liberec    104 445                    33
# 5              Olomouc    100 523                    26
# 6     České Budějovice     94 014                     7
# 7       Ústí nad Labem     92 952                    22
# 8       Hradec Králové     92 742                    21
# 9            Pardubice     90 688                    32
# 10                Zlín     74 997                    16
# 11             Havířov     71 903                     8
# 12              Kladno     69 054                     6
# 13                Most     66 186                     8
# 14               Opava     56 638                    16
# 15       Frýdek-Místek     55 931                     7
# 16             Karviná     52 824                     9
# 17             Jihlava     50 845                    16
# 18             Teplice     49 575                     7
# 19               Děčín     48 809                    35
# 20        Karlovy Vary     48 501                    15
# 21            Chomutov     48 720                     1
# 22  Jablonec nad Nisou     45 802                     8
# 23      Mladá Boleslav     44 489                    13
# 24           Prostějov     43 680                     7
# 25              Přerov     43 186                    13

# %% [markdown]
# ## Bonus: hezčí progress bar
#
# Knihovna [`tqdm`](https://tqdm.github.io/) (`pip install tqdm`) kreslí hezký progress bar a počítá čas do konce.

# %%
from tqdm import tqdm

municipalities = []
for city in tqdm(cities_links):
    time.sleep(1)
    
    url = 'https://cs.wikipedia.org/{}'.format(city['href'])
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    municipalities.append(soup.select_one('.infobox a[title*="Část obce"]').find_next('td').contents[0].strip())
cities_df['Municipalities number'] = municipalities
cities_df
# Out:
# 100%|██████████| 26/26 [00:38<00:00,  1.50s/it]
#                   City Population Municipalities number
# 0                Praha  1 308 632                   146
# 1                 Brno    380 681                    48
# 2              Ostrava    289 128                    37
# 3                Plzeň    172 441                    31
# 4              Liberec    104 445                    33
# 5              Olomouc    100 523                    26
# 6     České Budějovice     94 014                     7
# 7       Ústí nad Labem     92 952                    22
# 8       Hradec Králové     92 742                    21
# 9            Pardubice     90 688                    32
# 10                Zlín     74 997                    16
# 11             Havířov     71 903                     8
# 12              Kladno     69 054                     6
# 13                Most     66 186                     8
# 14               Opava     56 638                    16
# 15       Frýdek-Místek     55 931                     7
# 16             Karviná     52 824                     9
# 17             Jihlava     50 845                    16
# 18             Teplice     49 575                     7
# 19               Děčín     48 809                    35
# 20        Karlovy Vary     48 501                    15
# 21            Chomutov     48 720                     1
# 22  Jablonec nad Nisou     45 802                     8
# 23      Mladá Boleslav     44 489                    13
# 24           Prostějov     43 680                     7
# 25              Přerov     43 186                    13

# %% [markdown]
# # Cvičení 5.3
#
# Vytvořte tabulku z [http://quotes.toscrape.com/](http://quotes.toscrape.com/), kde první sloupec bude jméno autora a druhý sloupec bude jeho datum narození.
